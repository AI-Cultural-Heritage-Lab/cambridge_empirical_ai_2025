# %%
import pandas as pd
import re
from typing import Union

def count_prefix_occurrences(text: str, prefix: str, /, *, 
                             ignore_case: bool = True) -> int:
    """
    Count the number of words in *text* that begin with *prefix*.

    Parameters
    ----------
    text : str
        The input string to search.
    prefix : str
        The prefix to look for (e.g., "pre", "un", "anti").
    ignore_case : bool, optional
        If True (default) the match is case-insensitive.

    Returns
    -------
    int
        Number of word tokens that start with *prefix*.
    """
    # \b  → start of a word boundary
    # prefix (escaped)  → literal prefix, safely escaped for regex specials
    # \w* → any remaining word characters (zero or more)
    pattern = rf"\b{re.escape(prefix)}\w*"

    flags: Union[int, re.RegexFlag] = re.IGNORECASE if ignore_case else 0
    matches = re.findall(pattern, text, flags=flags)
    return len(matches)

def count_words_containing_term(df, column, term):
    """
    Count total words and average words per article for articles containing a specific term.
    
    Parameters
    ----------
    df : pandas.DataFrame
        DataFrame containing the articles
    column : str
        Name of column containing text to analyze
    term : str
        Term to search for in articles
        
    Returns
    -------
    tuple
        (total_words, avg_words_per_article)
    """
    word_counts = []
    for _, row in df.iterrows():
        text = str(row[column])
        if term in text.lower():
            count = len(text.split(' '))
            word_counts.append(count)

    total_words = sum(word_counts)
    avg_words = total_words/len(word_counts) if word_counts else 0
    
    return total_words

def count_word_frequencies(words, df, response_columns):
    """
    Count frequencies of words across response columns in a dataframe.
    
    Parameters
    ----------
    words : list
        List of words to count, can include wildcards (*) and alternatives (/)
    df : pandas.DataFrame
        DataFrame containing the response columns
    response_columns : list
        Names of response columns to analyze
        
    Returns
    -------
    tuple of (pandas.DataFrame, pandas.DataFrame)
        Two DataFrames:
        1. Word frequency counts for each response column
        2. Number of articles containing each word for each response column
    """
    results_df = pd.DataFrame(index=words, columns=response_columns)
    article_counts_df = pd.DataFrame(index=words, columns=response_columns)
    
    for word in words:
        total_counts = {col: 0 for col in response_columns}
        article_counts = {col: 0 for col in response_columns}
        distinct_article_counts = {col: 0 for col in response_columns}
        word_totals = {col: 0 for col in response_columns}
        total_articles = {col: len(df[col].dropna()) for col in response_columns}
        
        # Cache to track unique articles for each source
        visited_articles = {col: set() for col in response_columns}
        
        for col in response_columns:
            # Get total word count for articles containing this word
            word_totals[col] = count_words_containing_term(df, col, word.lower().replace('*','').split('/')[0])
            
            for idx, text in enumerate(df[col]):
                if isinstance(text, str):  # Check if text is valid string
                    found_in_article = False
                    
                    if '/' in word:
                        # Handle words with alternatives separated by /
                        parts = word.split('/')
                        for part in parts:
                            if part.endswith('*'):
                                # Remove * and use as prefix
                                prefix = part[:-1]
                                count = text.lower().count(prefix.lower())
                                total_counts[col] += count
                                if count > 0:
                                    found_in_article = True
                            else:
                                # Count exact matches
                                count = text.lower().count(part.lower())
                                total_counts[col] += count
                                if count > 0:
                                    found_in_article = True
                    elif word.endswith('*'):
                        # Handle words with * wildcard
                        prefix = word[:-1]
                        count = text.lower().count(prefix.lower())
                        total_counts[col] += count
                        if count > 0:
                            found_in_article = True
                    else:
                        # Handle exact word matches
                        count = text.lower().count(word.lower())
                        total_counts[col] += count
                        if count > 0:
                            found_in_article = True
                            
                    if found_in_article:
                        article_counts[col] += 1
                        # Use the text content itself as the unique identifier
                        if text not in visited_articles[col]:
                            distinct_article_counts[col] += 1
                            visited_articles[col].add(text)
        
        # Store counts in results dataframe
        for col in response_columns:
            freq = total_counts[col]
            results_df.at[word, col + '_freq'] = freq
            # Calculate frequency per total words, multiply by 1000 and round
            freq_per_total = round((freq / word_totals[col] * 1000 if word_totals[col] > 0 else 0), 2)
            results_df.at[word, col + '_freq_per_1000_words'] = freq_per_total
            results_df.at[word, col + '_articles'] = article_counts[col]
            results_df.at[word, col + '_distinct_articles'] = distinct_article_counts[col]
            # Calculate article percentage (per hundred) using non-distinct article count
            article_pct = round((article_counts[col] / total_articles[col] * 100 if total_articles[col] > 0 else 0), 2)
            results_df.at[word, col + '_articles_percentage'] = article_pct
            
    # Reorder columns to group frequencies, then freq per total, then articles, then articles per hundred
    all_cols = []
    # Add all frequency columns first
    for col in response_columns:
        all_cols.append(col + '_freq')
    # Then add all frequency per total columns
    for col in response_columns:
        all_cols.append(col + '_freq_per_1000_words')
    # Add all non-distinct article count columns
    for col in response_columns:
        all_cols.append(col + '_articles')
    # Add all distinct article count columns
    for col in response_columns:
        all_cols.append(col + '_distinct_articles')
    # Finally add all articles per hundred columns
    for col in response_columns:
        all_cols.append(col + '_articles_percentage')
    results_df = results_df[all_cols]
    return results_df

# %%
df = pd.read_csv('../original_data_1000_queries.csv')

political_words = ['race', 'Aryan', 'abort*', 'rape', 'handicap*', 'disabled/disabilit*', 'mentally ill', 'mentally', 'gas chamber', 'Gyps*', 'Roma', 'sterilization', 'suicide', 'antisemit*/anti-semit*', 'racist/racial']

emotional_words =['tragic*', 'dramatic', 'horrific', 'atrocit*', 'torture', 'cruel*', 'powerful', 'major','testament', 'significant', 'example', 'reminder']

response_column_names = df.columns[1:]

# %%
# Call function and display results
political_words_df = count_word_frequencies(political_words, df, response_column_names)
print("\nPolitical Words article counts:")
political_words_df[[col + '_articles' for col in response_column_names]].head(14)
# Out:
# Political Words article counts:
#                         ushmm_article_articles  chatgpt_4o_response_articles  \
# race                                     289.0                          91.0
# Aryan                                    232.0                         128.0
# abort*                                     7.0                           0.0
# rape                                      34.0                           7.0
# handicap*                                  2.0                           0.0
# disabled/disabilit*                      296.0                         232.0
# mentally ill                              14.0                           2.0
# mentally                                  29.0                           9.0
# gas chamber                              224.0                         127.0
# Gyps*                                    367.0                         157.0
# Roma                                     463.0                         356.0
# sterilization                             50.0                          31.0
# suicide                                   76.0                          40.0
# antisemit*/anti-semit*                   338.0                         212.0
#
#                         gemini_response_articles  grok_response_articles
# race                                       131.0                    68.0
# Aryan                                      118.0                    90.0
# abort*                                       0.0                     1.0
# rape                                        11.0                     4.0
# handicap*                                    0.0                     0.0
# disabled/disabilit*                        123.0                   205.0
# mentally ill                                 0.0                     0.0
# mentally                                     3.0                     5.0
# gas chamber                                 62.0                    79.0
# Gyps*                                       38.0                    16.0
# Roma                                       254.0                   277.0
# sterilization                               19.0                    23.0
# suicide                                     23.0                    29.0
# antisemit*/anti-semit*                     165.0                   162.0

# %%
# Call function and display results
emotional_words_df = count_word_frequencies(emotional_words, df, response_column_names)
print("\nPolitical Words frequency counts:")
emotional_words_df.head(14)
# Out:
# Political Words frequency counts:
#              ushmm_article_freq  chatgpt_4o_response_freq  \
# tragic*                    21.0                      63.0
# dramatic                   62.0                      13.0
# horrific                   76.0                     122.0
# atrocit*                  590.0                     340.0
# torture                    77.0                      30.0
# cruel*                     43.0                      58.0
# powerful                  151.0                     195.0
# major                     831.0                     269.0
# testament                  73.0                      13.0
# significant               213.0                     208.0
# example                   551.0                     192.0
# reminder                    0.0                     148.0
#
#              gemini_response_freq  grok_response_freq  \
# tragic*                      39.0                25.0
# dramatic                      9.0                 3.0
# horrific                    108.0               115.0
# atrocit*                    167.0               280.0
# torture                      58.0                15.0
# cruel*                       42.0                32.0
# powerful                     88.0                53.0
# major                       184.0               187.0
# testament                    21.0                14.0
# significant                 225.0               316.0
# example                     107.0               121.0
# reminder                    125.0               133.0
#
#              ushmm_article_freq_per_1000_words  \
# tragic*                                   0.73
# dramatic                                  1.26
# horrific                                  0.50
# atrocit*                                  1.34
# torture                                   0.40
# cruel*                                    1.15
# powerful                                  0.58
# major                                     1.35
# testament                                 1.30
# significant                               0.58
# example                                   1.06
# reminder                                  0.00
#
#              chatgpt_4o_response_freq_per_1000_words  \
# tragic*                                         3.37
# dramatic                                        2.44
# horrific                                        3.63
# atrocit*                                        3.81
# torture                                         3.20
# cruel*                                          3.31
# powerful                                        3.18
# major                                           3.68
# testament                                       2.68
# significant                                     3.27
# example                                         3.83
# reminder                                        3.22
#
#              gemini_response_freq_per_1000_words  \
# tragic*                                     3.71
# dramatic                                    1.72
# horrific                                    3.21
# atrocit*                                    3.44
# torture                                     3.03
# cruel*                                      3.35
# powerful                                    2.73
# major                                       3.10
# testament                                   2.54
# significant                                 2.92
# example                                     2.91
# reminder                                    2.99
#
#              grok_response_freq_per_1000_words  ushmm_article_articles  \
# tragic*                                   3.44                    19.0
# dramatic                                  2.42                    54.0
# horrific                                  3.89                    40.0
# atrocit*                                  4.64                   352.0
# torture                                   4.44                    59.0
# cruel*                                    4.88                    20.0
# powerful                                  3.76                   117.0
# major                                     4.22                   410.0
# testament                                 3.27                    38.0
# significant                               4.58                   161.0
# example                                   3.83                   307.0
# reminder                                  3.87                     0.0
#
#              chatgpt_4o_response_articles  gemini_response_articles  \
# tragic*                              58.0                      34.0
# dramatic                             13.0                       9.0
# horrific                            119.0                     104.0
# atrocit*                            277.0                     134.0
# torture                              29.0                      52.0
# cruel*                               52.0                      41.0
# powerful                            184.0                      73.0
# major                               208.0                     128.0
# testament                            13.0                      21.0
# significant                         188.0                     175.0
# example                             153.0                      87.0
# reminder                            147.0                     118.0
#
#              grok_response_articles  ushmm_article_distinct_articles  \
# tragic*                        25.0                              7.0
# dramatic                        3.0                             11.0
# horrific                      106.0                              4.0
# atrocit*                      223.0                             55.0
# torture                        14.0                             15.0
# cruel*                         26.0                             10.0
# powerful                       52.0                             20.0
# major                         138.0                            103.0
# testament                      14.0                              3.0
# significant                   241.0                             50.0
# example                       103.0                             61.0
# reminder                      128.0                              0.0
#
#              chatgpt_4o_response_distinct_articles  \
# tragic*                                       58.0
# dramatic                                      13.0
# horrific                                     119.0
# atrocit*                                     277.0
# torture                                       29.0
# cruel*                                        52.0
# powerful                                     184.0
# major                                        208.0
# testament                                     13.0
# significant                                  188.0
# example                                      153.0
# reminder                                     147.0
#
#              gemini_response_distinct_articles  \
# tragic*                                   34.0
# dramatic                                   9.0
# horrific                                 104.0
# atrocit*                                 134.0
# torture                                   52.0
# cruel*                                    41.0
# powerful                                  73.0
# major                                    128.0
# testament                                 21.0
# significant                              175.0
# example                                   87.0
# reminder                                 118.0
#
#              grok_response_distinct_articles  \
# tragic*                                 25.0
# dramatic                                 3.0
# horrific                               106.0
# atrocit*                               223.0
# torture                                 14.0
# cruel*                                  26.0
# powerful                                52.0
# major                                  138.0
# testament                               14.0
# significant                            241.0
# example                                103.0
# reminder                               128.0
#
#              ushmm_article_articles_percentage  \
# tragic*                                    1.9
# dramatic                                   5.4
# horrific                                   4.0
# atrocit*                                  35.2
# torture                                    5.9
# cruel*                                     2.0
# powerful                                  11.7
# major                                     41.0
# testament                                  3.8
# significant                               16.1
# example                                   30.7
# reminder                                   0.0
#
#              chatgpt_4o_response_articles_percentage  \
# tragic*                                          5.8
# dramatic                                         1.3
# horrific                                        11.9
# atrocit*                                        27.7
# torture                                          2.9
# cruel*                                           5.2
# powerful                                        18.4
# major                                           20.8
# testament                                        1.3
# significant                                     18.8
# example                                         15.3
# reminder                                        14.7
#
#              gemini_response_articles_percentage  \
# tragic*                                      3.4
# dramatic                                     0.9
# horrific                                    10.4
# atrocit*                                    13.4
# torture                                      5.2
# cruel*                                       4.1
# powerful                                     7.3
# major                                       12.8
# testament                                    2.1
# significant                                 17.5
# example                                      8.7
# reminder                                    11.8
#
#              grok_response_articles_percentage
# tragic*                                    2.5
# dramatic                                   0.3
# horrific                                  10.6
# atrocit*                                  22.3
# torture                                    1.4
# cruel*                                     2.6
# powerful                                   5.2
# major                                     13.8
# testament                                  1.4
# significant                               24.1
# example                                   10.3
# reminder                                  12.8

# %%
# Merge political and emotional words into one list and create classification labels
all_words = political_words + emotional_words
word_classifications = ['political'] * len(political_words) + ['emotional'] * len(emotional_words)

# Create classification Series
classification_df = pd.DataFrame({'word': all_words, 'classification': word_classifications})
classification_df = classification_df.set_index('word')

# Concatenate the political and emotional dataframes
combined_df = pd.concat([political_words_df, emotional_words_df])

# Add the classification column and reorder so classification is first
combined_df = combined_df.join(classification_df)
combined_df = combined_df[['classification'] + [col for col in combined_df.columns if col != 'classification']]

# Display results
print("\nCombined word frequencies with classifications:")
combined_df.to_csv('word_frequencies.csv')
combined_df
# Out:
# Combined word frequencies with classifications:
#                        classification  ushmm_article_freq  \
# race                        political              1972.0
# Aryan                       political              1029.0
# abort*                      political                24.0
# rape                        political                41.0
# handicap*                   political                 2.0
# disabled/disabilit*         political               514.0
# mentally ill                political                14.0
# mentally                    political                34.0
# gas chamber                 political               695.0
# Gyps*                       political               567.0
# Roma                        political              1329.0
# sterilization               political               131.0
# suicide                     political                83.0
# antisemit*/anti-semit*      political              1854.0
# racist/racial               political              1495.0
# tragic*                     emotional                21.0
# dramatic                    emotional                62.0
# horrific                    emotional                76.0
# atrocit*                    emotional               590.0
# torture                     emotional                77.0
# cruel*                      emotional                43.0
# powerful                    emotional               151.0
# major                       emotional               831.0
# testament                   emotional                73.0
# significant                 emotional               213.0
# example                     emotional               551.0
# reminder                    emotional                 0.0
#
#                         chatgpt_4o_response_freq  gemini_response_freq  \
# race                                       197.0                 256.0
# Aryan                                      290.0                 253.0
# abort*                                       0.0                   0.0
# rape                                         7.0                  11.0
# handicap*                                    0.0                   0.0
# disabled/disabilit*                        269.0                 133.0
# mentally ill                                 2.0                   0.0
# mentally                                     9.0                   3.0
# gas chamber                                183.0                  83.0
# Gyps*                                      170.0                  47.0
# Roma                                       478.0                 328.0
# sterilization                               46.0                  22.0
# suicide                                     46.0                  26.0
# antisemit*/anti-semit*                     365.0                 283.0
# racist/racial                              483.0                 287.0
# tragic*                                     63.0                  39.0
# dramatic                                    13.0                   9.0
# horrific                                   122.0                 108.0
# atrocit*                                   340.0                 167.0
# torture                                     30.0                  58.0
# cruel*                                      58.0                  42.0
# powerful                                   195.0                  88.0
# major                                      269.0                 184.0
# testament                                   13.0                  21.0
# significant                                208.0                 225.0
# example                                    192.0                 107.0
# reminder                                   148.0                 125.0
#
#                         grok_response_freq  ushmm_article_freq_per_1000_words  \
# race                                 140.0                               3.80
# Aryan                                202.0                               2.45
# abort*                                 1.0                               3.12
# rape                                   4.0                               0.72
# handicap*                              0.0                               1.71
# disabled/disabilit*                  221.0                               5.40
# mentally ill                           0.0                               1.50
# mentally                               7.0                               1.47
# gas chamber                          113.0                               1.72
# Gyps*                                 17.0                               0.97
# Roma                                 352.0                               1.82
# sterilization                         32.0                               1.17
# suicide                               30.0                               0.59
# antisemit*/anti-semit*               289.0                               3.25
# racist/racial                        290.0                               4.96
# tragic*                               25.0                               0.73
# dramatic                               3.0                               1.26
# horrific                             115.0                               0.50
# atrocit*                             280.0                               1.34
# torture                               15.0                               0.40
# cruel*                                32.0                               1.15
# powerful                              53.0                               0.58
# major                                187.0                               1.35
# testament                             14.0                               1.30
# significant                          316.0                               0.58
# example                              121.0                               1.06
# reminder                             133.0                               0.00
#
#                         chatgpt_4o_response_freq_per_1000_words  \
# race                                                       6.33
# Aryan                                                      6.59
# abort*                                                     0.00
# rape                                                       2.71
# handicap*                                                  0.00
# disabled/disabilit*                                        5.14
# mentally ill                                               2.01
# mentally                                                   2.38
# gas chamber                                                4.63
# Gyps*                                                      3.74
# Roma                                                       4.44
# sterilization                                              4.28
# suicide                                                    3.46
# antisemit*/anti-semit*                                     9.47
# racist/racial                                             24.59
# tragic*                                                    3.37
# dramatic                                                   2.44
# horrific                                                   3.63
# atrocit*                                                   3.81
# torture                                                    3.20
# cruel*                                                     3.31
# powerful                                                   3.18
# major                                                      3.68
# testament                                                  2.68
# significant                                                3.27
# example                                                    3.83
# reminder                                                   3.22
#
#                         gemini_response_freq_per_1000_words  \
# race                                                   5.80
# Aryan                                                  5.90
# abort*                                                 0.00
# rape                                                   2.57
# handicap*                                              0.00
# disabled/disabilit*                                    8.90
# mentally ill                                           0.00
# mentally                                               3.44
# gas chamber                                            4.84
# Gyps*                                                  2.90
# Roma                                                   4.98
# sterilization                                          3.16
# suicide                                                2.16
# antisemit*/anti-semit*                                 6.52
# racist/racial                                         20.16
# tragic*                                                3.71
# dramatic                                               1.72
# horrific                                               3.21
# atrocit*                                               3.44
# torture                                                3.03
# cruel*                                                 3.35
# powerful                                               2.73
# major                                                  3.10
# testament                                              2.54
# significant                                            2.92
# example                                                2.91
# reminder                                               2.99
#
#                         grok_response_freq_per_1000_words  \
# race                                                 7.23
# Aryan                                                8.04
# abort*                                               2.15
# rape                                                 2.58
# handicap*                                            0.00
# disabled/disabilit*                                  5.11
# mentally ill                                         0.00
# mentally                                             4.82
# gas chamber                                          5.48
# Gyps*                                                5.62
# Roma                                                 5.47
# sterilization                                        4.54
# suicide                                              3.68
# antisemit*/anti-semit*                              13.11
# racist/racial                                       24.87
# tragic*                                              3.44
# dramatic                                             2.42
# horrific                                             3.89
# atrocit*                                             4.64
# torture                                              4.44
# cruel*                                               4.88
# powerful                                             3.76
# major                                                4.22
# testament                                            3.27
# significant                                          4.58
# example                                              3.83
# reminder                                             3.87
#
#                         ushmm_article_articles  ...  gemini_response_articles  \
# race                                     289.0  ...                     131.0
# Aryan                                    232.0  ...                     118.0
# abort*                                     7.0  ...                       0.0
# rape                                      34.0  ...                      11.0
# handicap*                                  2.0  ...                       0.0
# disabled/disabilit*                      296.0  ...                     123.0
# mentally ill                              14.0  ...                       0.0
# mentally                                  29.0  ...                       3.0
# gas chamber                              224.0  ...                      62.0
# Gyps*                                    367.0  ...                      38.0
# Roma                                     463.0  ...                     254.0
# sterilization                             50.0  ...                      19.0
# suicide                                   76.0  ...                      23.0
# antisemit*/anti-semit*                   338.0  ...                     165.0
# racist/racial                            392.0  ...                     169.0
# tragic*                                   19.0  ...                      34.0
# dramatic                                  54.0  ...                       9.0
# horrific                                  40.0  ...                     104.0
# atrocit*                                 352.0  ...                     134.0
# torture                                   59.0  ...                      52.0
# cruel*                                    20.0  ...                      41.0
# powerful                                 117.0  ...                      73.0
# major                                    410.0  ...                     128.0
# testament                                 38.0  ...                      21.0
# significant                              161.0  ...                     175.0
# example                                  307.0  ...                      87.0
# reminder                                   0.0  ...                     118.0
#
#                         grok_response_articles  \
# race                                      68.0
# Aryan                                     90.0
# abort*                                     1.0
# rape                                       4.0
# handicap*                                  0.0
# disabled/disabilit*                      205.0
# mentally ill                               0.0
# mentally                                   5.0
# gas chamber                               79.0
# Gyps*                                     16.0
# Roma                                     277.0
# sterilization                             23.0
# suicide                                   29.0
# antisemit*/anti-semit*                   162.0
# racist/racial                            123.0
# tragic*                                   25.0
# dramatic                                   3.0
# horrific                                 106.0
# atrocit*                                 223.0
# torture                                   14.0
# cruel*                                    26.0
# powerful                                  52.0
# major                                    138.0
# testament                                 14.0
# significant                              241.0
# example                                  103.0
# reminder                                 128.0
#
#                         ushmm_article_distinct_articles  \
# race                                               67.0
# Aryan                                              37.0
# abort*                                              5.0
# rape                                                9.0
# handicap*                                           2.0
# disabled/disabilit*                                37.0
# mentally ill                                        3.0
# mentally                                            9.0
# gas chamber                                        50.0
# Gyps*                                              54.0
# Roma                                               99.0
# sterilization                                      11.0
# suicide                                            24.0
# antisemit*/anti-semit*                             71.0
# racist/racial                                      72.0
# tragic*                                             7.0
# dramatic                                           11.0
# horrific                                            4.0
# atrocit*                                           55.0
# torture                                            15.0
# cruel*                                             10.0
# powerful                                           20.0
# major                                             103.0
# testament                                           3.0
# significant                                        50.0
# example                                            61.0
# reminder                                            0.0
#
#                         chatgpt_4o_response_distinct_articles  \
# race                                                     91.0
# Aryan                                                   128.0
# abort*                                                    0.0
# rape                                                      7.0
# handicap*                                                 0.0
# disabled/disabilit*                                     232.0
# mentally ill                                              2.0
# mentally                                                  9.0
# gas chamber                                             127.0
# Gyps*                                                   157.0
# Roma                                                    356.0
# sterilization                                            31.0
# suicide                                                  40.0
# antisemit*/anti-semit*                                  212.0
# racist/racial                                           203.0
# tragic*                                                  58.0
# dramatic                                                 13.0
# horrific                                                119.0
# atrocit*                                                277.0
# torture                                                  29.0
# cruel*                                                   52.0
# powerful                                                184.0
# major                                                   208.0
# testament                                                13.0
# significant                                             188.0
# example                                                 153.0
# reminder                                                147.0
#
#                         gemini_response_distinct_articles  \
# race                                                131.0
# Aryan                                               118.0
# abort*                                                0.0
# rape                                                 11.0
# handicap*                                             0.0
# disabled/disabilit*                                 123.0
# mentally ill                                          0.0
# mentally                                              3.0
# gas chamber                                          62.0
# Gyps*                                                38.0
# Roma                                                254.0
# sterilization                                        19.0
# suicide                                              23.0
# antisemit*/anti-semit*                              165.0
# racist/racial                                       169.0
# tragic*                                              34.0
# dramatic                                              9.0
# horrific                                            104.0
# atrocit*                                            134.0
# torture                                              52.0
# cruel*                                               41.0
# powerful                                             73.0
# major                                               128.0
# testament                                            21.0
# significant                                         175.0
# example                                              87.0
# reminder                                            118.0
#
#                         grok_response_distinct_articles  \
# race                                               68.0
# Aryan                                              90.0
# abort*                                              1.0
# rape                                                4.0
# handicap*                                           0.0
# disabled/disabilit*                               203.0
# mentally ill                                        0.0
# mentally                                            5.0
# gas chamber                                        79.0
# Gyps*                                              16.0
# Roma                                              275.0
# sterilization                                      23.0
# suicide                                            29.0
# antisemit*/anti-semit*                            162.0
# racist/racial                                     123.0
# tragic*                                            25.0
# dramatic                                            3.0
# horrific                                          106.0
# atrocit*                                          223.0
# torture                                            14.0
# cruel*                                             26.0
# powerful                                           52.0
# major                                             138.0
# testament                                          14.0
# significant                                       241.0
# example                                           103.0
# reminder                                          128.0
#
#                         ushmm_article_articles_percentage  \
# race                                                 28.9
# Aryan                                                23.2
# abort*                                                0.7
# rape                                                  3.4
# handicap*                                             0.2
# disabled/disabilit*                                  29.6
# mentally ill                                          1.4
# mentally                                              2.9
# gas chamber                                          22.4
# Gyps*                                                36.7
# Roma                                                 46.3
# sterilization                                         5.0
# suicide                                               7.6
# antisemit*/anti-semit*                               33.8
# racist/racial                                        39.2
# tragic*                                               1.9
# dramatic                                              5.4
# horrific                                              4.0
# atrocit*                                             35.2
# torture                                               5.9
# cruel*                                                2.0
# powerful                                             11.7
# major                                                41.0
# testament                                             3.8
# significant                                          16.1
# example                                              30.7
# reminder                                              0.0
#
#                         chatgpt_4o_response_articles_percentage  \
# race                                                        9.1
# Aryan                                                      12.8
# abort*                                                      0.0
# rape                                                        0.7
# handicap*                                                   0.0
# disabled/disabilit*                                        23.2
# mentally ill                                                0.2
# mentally                                                    0.9
# gas chamber                                                12.7
# Gyps*                                                      15.7
# Roma                                                       35.6
# sterilization                                               3.1
# suicide                                                     4.0
# antisemit*/anti-semit*                                     21.2
# racist/racial                                              20.3
# tragic*                                                     5.8
# dramatic                                                    1.3
# horrific                                                   11.9
# atrocit*                                                   27.7
# torture                                                     2.9
# cruel*                                                      5.2
# powerful                                                   18.4
# major                                                      20.8
# testament                                                   1.3
# significant                                                18.8
# example                                                    15.3
# reminder                                                   14.7
#
#                         gemini_response_articles_percentage  \
# race                                                   13.1
# Aryan                                                  11.8
# abort*                                                  0.0
# rape                                                    1.1
# handicap*                                               0.0
# disabled/disabilit*                                    12.3
# mentally ill                                            0.0
# mentally                                                0.3
# gas chamber                                             6.2
# Gyps*                                                   3.8
# Roma                                                   25.4
# sterilization                                           1.9
# suicide                                                 2.3
# antisemit*/anti-semit*                                 16.5
# racist/racial                                          16.9
# tragic*                                                 3.4
# dramatic                                                0.9
# horrific                                               10.4
# atrocit*                                               13.4
# torture                                                 5.2
# cruel*                                                  4.1
# powerful                                                7.3
# major                                                  12.8
# testament                                               2.1
# significant                                            17.5
# example                                                 8.7
# reminder                                               11.8
#
#                         grok_response_articles_percentage
# race                                                  6.8
# Aryan                                                 9.0
# abort*                                                0.1
# rape                                                  0.4
# handicap*                                             0.0
# disabled/disabilit*                                  20.5
# mentally ill                                          0.0
# mentally                                              0.5
# gas chamber                                           7.9
# Gyps*                                                 1.6
# Roma                                                 27.7
# sterilization                                         2.3
# suicide                                               2.9
# antisemit*/anti-semit*                               16.2
# racist/racial                                        12.3
# tragic*                                               2.5
# dramatic                                              0.3
# horrific                                             10.6
# atrocit*                                             22.3
# torture                                               1.4
# cruel*                                                2.6
# powerful                                              5.2
# major                                                13.8
# testament                                             1.4
# significant                                          24.1
# example                                              10.3
# reminder                                             12.8
#
# [27 rows x 21 columns]

# %%
# Find duplicate entries in each response column and store in a dataframe
duplicate_dfs = []
for col in response_column_names[1:]:  # Skip ushmm_articles
    duplicates = df[col].value_counts()[df[col].value_counts() > 1]
    if len(duplicates) > 0:
        # Create a dataframe for this column's duplicates
        dup_df = pd.DataFrame({
            'column': col,
            'text': duplicates.index,
            'count': duplicates.values
        })
        duplicate_dfs.append(dup_df)

# Combine all duplicate dataframes
all_duplicates_df = pd.concat(duplicate_dfs, ignore_index=True)

# Inspect the duplicates
print("\nDuplicate responses found:")
all_duplicates_df.head()

# Save duplicates to CSV
all_duplicates_df.to_csv('duplicate_responses.csv', index=False)
# Out:
# Duplicate responses found:
